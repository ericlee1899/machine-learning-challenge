# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# Out:
# Collecting sklearn
#   Using cached sklearn-0.0.tar.gz (1.1 kB)
# Requirement already satisfied, skipping upgrade: scikit-learn in c:\users\ericl\anaconda3\lib\site-packages (from sklearn) (0.23.1)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in c:\users\ericl\anaconda3\lib\site-packages (from scikit-learn->sklearn) (0.16.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in c:\users\ericl\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.18.5)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in c:\users\ericl\anaconda3\lib\site-packages (from scikit-learn->sklearn) (2.1.0)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.1 in c:\users\ericl\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.5.0)
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py): started
#   Building wheel for sklearn (setup.py): finished with status 'done'
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1320 sha256=50f7ba685c5d3f82b28f653d603ddb30a070bb2ea8e8279d9a6cebaaeaeb7d69
#   Stored in directory: c:\users\ericl\appdata\local\pip\cache\wheels\22\0b\40\fd3f795caaa1fb4c6cb738bc1f56100be1e57da95849bfc897
# Successfully built sklearn
# Installing collected packages: sklearn
# Successfully installed sklearn-0.0

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in c:\users\ericl\anaconda3\lib\site-packages (0.16.0)

# %%
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet.csv")
df = df.drop(columns=["koi_teq", "koi_model_snr", "koi_tce_plnt_num", "ra", "dec", "koi_kepmag"])
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_insol_err2  koi_steff  koi_steff_err1  \
# 0          0.003520  ...           -1.62       5455              81
# 1          0.000581  ...          -10.49       5853             158
# 2          0.000115  ...         -230.35       5805             157
# 3          0.001130  ...         -314.24       6031             169
# 4          0.001900  ...         -136.70       6046             189
#
#    koi_steff_err2  koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  \
# 0             -81      4.467           0.064          -0.096     0.927
# 1            -176      4.544           0.044          -0.176     0.868
# 2            -174      4.564           0.053          -0.168     0.791
# 3            -211      4.438           0.070          -0.210     1.046
# 4            -232      4.486           0.054          -0.229     0.972
#
#    koi_srad_err1  koi_srad_err2
# 0          0.105         -0.061
# 1          0.233         -0.078
# 2          0.201         -0.067
# 3          0.334         -0.133
# 4          0.315         -0.105
#
# [5 rows x 35 columns]

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
target = df["koi_disposition"]
data = df.drop("koi_disposition", axis=1)
feature_names = data.columns
data.head()
# Out:
#    koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0              0              0              0              0   54.418383
# 1              0              1              0              0   19.899140
# 2              0              1              0              0    1.736952
# 3              0              0              0              0    2.525592
# 4              0              0              0              0    4.134435
#
#    koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0     2.479000e-04    -2.479000e-04   162.513840          0.003520
# 1     1.490000e-05    -1.490000e-05   175.850252          0.000581
# 2     2.630000e-07    -2.630000e-07   170.307565          0.000115
# 3     3.760000e-06    -3.760000e-06   171.595550          0.001130
# 4     1.050000e-05    -1.050000e-05   172.979370          0.001900
#
#    koi_time0bk_err2  ...  koi_insol_err2  koi_steff  koi_steff_err1  \
# 0         -0.003520  ...           -1.62       5455              81
# 1         -0.000581  ...          -10.49       5853             158
# 2         -0.000115  ...         -230.35       5805             157
# 3         -0.001130  ...         -314.24       6031             169
# 4         -0.001900  ...         -136.70       6046             189
#
#    koi_steff_err2  koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  \
# 0             -81      4.467           0.064          -0.096     0.927
# 1            -176      4.544           0.044          -0.176     0.868
# 2            -174      4.564           0.053          -0.168     0.791
# 3            -211      4.438           0.070          -0.210     1.046
# 4            -232      4.486           0.054          -0.229     0.972
#
#    koi_srad_err1  koi_srad_err2
# 0          0.105         -0.061
# 1          0.233         -0.078
# 2          0.201         -0.067
# 3          0.334         -0.133
# 4          0.315         -0.105
#
# [5 rows x 34 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 6122              0              0              0              0    6.768901
# 6370              0              1              0              1    0.733726
# 2879              1              0              0              0    7.652707
# 107               0              0              0              0    7.953547
# 29                0              0              0              0    4.959319
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 6122     7.380000e-05    -7.380000e-05   133.077240          0.008440
# 6370     6.060000e-06    -6.060000e-06   132.020050          0.007950
# 2879     6.540000e-05    -6.540000e-05   134.460380          0.006190
# 107      1.910000e-05    -1.910000e-05   174.662240          0.001820
# 29       5.150000e-07    -5.150000e-07   172.258529          0.000083
#
#       koi_time0bk_err2  ...  koi_insol_err2  koi_steff  koi_steff_err1  \
# 6122         -0.008440  ...         -103.87       5737             154
# 6370         -0.007950  ...         -677.78       5855             158
# 2879         -0.006190  ...          -64.34       6328             151
# 107          -0.001820  ...          -10.12       4768              76
# 29           -0.000083  ...          -93.21       5712              77
#
#       koi_steff_err2  koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  \
# 6122            -171      4.327           0.153          -0.187     1.125
# 6370            -175      4.578           0.033          -0.187     0.797
# 2879            -189      4.481           0.050          -0.200     0.963
# 107              -85      4.536           0.056          -0.016     0.779
# 29               -77      4.359           0.110          -0.110     1.082
#
#       koi_srad_err1  koi_srad_err2
# 6122          0.310         -0.207
# 6370          0.211         -0.056
# 2879          0.290         -0.097
# 107           0.023         -0.049
# 29            0.173         -0.130
#
# [5 rows x 34 columns]

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data
from sklearn.preprocessing import MinMaxScaler
X_minmax = MinMaxScaler().fit(X_train)
# y_minmax = MinMaxScaler().fit(y_train)

X_train_minmax = X_minmax.transform(X_train)
X_test_minmax = X_minmax.transform(X_test)
# y_train_minmax = y_minmax.transform(y_train)
# y_test_minmax = y_minmax.transform(y_test)

# %% [markdown]
# # Train the Model

# %%
from sklearn.svm import SVC 
model = SVC(kernel='linear')
model.fit(X_train_minmax, y_train)
print(f"Training Data Score: {model.score(X_train_minmax, y_train)}")
print(f"Testing Data Score: {model.score(X_test_minmax, y_test)}")
# Out:
# Training Data Score: 0.8401678428380698
# Testing Data Score: 0.835812356979405

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [1, 5, 10, 50],
              'gamma': [0.0001, 0.0005, 0.001, 0.005]}
grid = GridSearchCV(model, param_grid, verbose=3)

# %%
# Train the model with GridSearch
grid.fit(X_train_minmax, y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV] C=1, gamma=0.0001 ...............................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ................... C=1, gamma=0.0001, score=0.848, total=   0.3s
# [CV] C=1, gamma=0.0001 ...............................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [CV] ................... C=1, gamma=0.0001, score=0.831, total=   0.2s
# [CV] C=1, gamma=0.0001 ...............................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.4s remaining:    0.0s
# [CV] ................... C=1, gamma=0.0001, score=0.848, total=   0.2s
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ................... C=1, gamma=0.0001, score=0.823, total=   0.2s
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ................... C=1, gamma=0.0001, score=0.824, total=   0.3s
# [CV] C=1, gamma=0.0005 ...............................................
# [CV] ................... C=1, gamma=0.0005, score=0.848, total=   0.2s
# [CV] C=1, gamma=0.0005 ...............................................
# [CV] ................... C=1, gamma=0.0005, score=0.831, total=   0.2s
# [CV] C=1, gamma=0.0005 ...............................................
# [CV] ................... C=1, gamma=0.0005, score=0.848, total=   0.2s
# [CV] C=1, gamma=0.0005 ...............................................
# [CV] ................... C=1, gamma=0.0005, score=0.823, total=   0.2s
# [CV] C=1, gamma=0.0005 ...............................................
# [CV] ................... C=1, gamma=0.0005, score=0.824, total=   0.3s
# [CV] C=1, gamma=0.001 ................................................
# [CV] .................... C=1, gamma=0.001, score=0.848, total=   0.2s
# [CV] C=1, gamma=0.001 ................................................
# [CV] .................... C=1, gamma=0.001, score=0.831, total=   0.2s
# [CV] C=1, gamma=0.001 ................................................
# [CV] .................... C=1, gamma=0.001, score=0.848, total=   0.2s
# [CV] C=1, gamma=0.001 ................................................
# [CV] .................... C=1, gamma=0.001, score=0.823, total=   0.2s
# [CV] C=1, gamma=0.001 ................................................
# [CV] .................... C=1, gamma=0.001, score=0.824, total=   0.3s
# [CV] C=1, gamma=0.005 ................................................
# [CV] .................... C=1, gamma=0.005, score=0.848, total=   0.2s
# [CV] C=1, gamma=0.005 ................................................
# [CV] .................... C=1, gamma=0.005, score=0.831, total=   0.2s
# [CV] C=1, gamma=0.005 ................................................
# [CV] .................... C=1, gamma=0.005, score=0.848, total=   0.2s
# [CV] C=1, gamma=0.005 ................................................
# [CV] .................... C=1, gamma=0.005, score=0.823, total=   0.2s
# [CV] C=1, gamma=0.005 ................................................
# [CV] .................... C=1, gamma=0.005, score=0.824, total=   0.2s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ................... C=5, gamma=0.0001, score=0.867, total=   0.3s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ................... C=5, gamma=0.0001, score=0.855, total=   0.3s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ................... C=5, gamma=0.0001, score=0.869, total=   0.2s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ................... C=5, gamma=0.0001, score=0.843, total=   0.3s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ................... C=5, gamma=0.0001, score=0.855, total=   0.3s
# [CV] C=5, gamma=0.0005 ...............................................
# [CV] ................... C=5, gamma=0.0005, score=0.867, total=   0.3s
# [CV] C=5, gamma=0.0005 ...............................................
# [CV] ................... C=5, gamma=0.0005, score=0.855, total=   0.3s
# [CV] C=5, gamma=0.0005 ...............................................
# [CV] ................... C=5, gamma=0.0005, score=0.869, total=   0.3s
# [CV] C=5, gamma=0.0005 ...............................................
# [CV] ................... C=5, gamma=0.0005, score=0.843, total=   0.3s
# [CV] C=5, gamma=0.0005 ...............................................
# [CV] ................... C=5, gamma=0.0005, score=0.855, total=   0.2s
# [CV] C=5, gamma=0.001 ................................................
# [CV] .................... C=5, gamma=0.001, score=0.867, total=   0.2s
# [CV] C=5, gamma=0.001 ................................................
# [CV] .................... C=5, gamma=0.001, score=0.855, total=   0.2s
# [CV] C=5, gamma=0.001 ................................................
# [CV] .................... C=5, gamma=0.001, score=0.869, total=   0.2s
# [CV] C=5, gamma=0.001 ................................................
# [CV] .................... C=5, gamma=0.001, score=0.843, total=   0.3s
# [CV] C=5, gamma=0.001 ................................................
# [CV] .................... C=5, gamma=0.001, score=0.855, total=   0.2s
# [CV] C=5, gamma=0.005 ................................................
# [CV] .................... C=5, gamma=0.005, score=0.867, total=   0.3s
# [CV] C=5, gamma=0.005 ................................................
# [CV] .................... C=5, gamma=0.005, score=0.855, total=   0.3s
# [CV] C=5, gamma=0.005 ................................................
# [CV] .................... C=5, gamma=0.005, score=0.869, total=   0.2s
# [CV] C=5, gamma=0.005 ................................................
# [CV] .................... C=5, gamma=0.005, score=0.843, total=   0.3s
# [CV] C=5, gamma=0.005 ................................................
# [CV] .................... C=5, gamma=0.005, score=0.855, total=   0.3s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] .................. C=10, gamma=0.0001, score=0.879, total=   0.3s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] .................. C=10, gamma=0.0001, score=0.861, total=   0.2s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] .................. C=10, gamma=0.0001, score=0.872, total=   0.3s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] .................. C=10, gamma=0.0001, score=0.846, total=   0.2s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] .................. C=10, gamma=0.0001, score=0.865, total=   0.3s
# [CV] C=10, gamma=0.0005 ..............................................
# [CV] .................. C=10, gamma=0.0005, score=0.879, total=   0.2s
# [CV] C=10, gamma=0.0005 ..............................................
# [CV] .................. C=10, gamma=0.0005, score=0.861, total=   0.3s
# [CV] C=10, gamma=0.0005 ..............................................
# [CV] .................. C=10, gamma=0.0005, score=0.872, total=   0.3s
# [CV] C=10, gamma=0.0005 ..............................................
# [CV] .................. C=10, gamma=0.0005, score=0.846, total=   0.2s
# [CV] C=10, gamma=0.0005 ..............................................
# [CV] .................. C=10, gamma=0.0005, score=0.865, total=   0.3s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ................... C=10, gamma=0.001, score=0.879, total=   0.3s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ................... C=10, gamma=0.001, score=0.861, total=   0.3s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ................... C=10, gamma=0.001, score=0.872, total=   0.3s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ................... C=10, gamma=0.001, score=0.846, total=   0.3s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ................... C=10, gamma=0.001, score=0.865, total=   0.2s
# [CV] C=10, gamma=0.005 ...............................................
# [CV] ................... C=10, gamma=0.005, score=0.879, total=   0.3s
# [CV] C=10, gamma=0.005 ...............................................
# [CV] ................... C=10, gamma=0.005, score=0.861, total=   0.3s
# [CV] C=10, gamma=0.005 ...............................................
# [CV] ................... C=10, gamma=0.005, score=0.872, total=   0.2s
# [CV] C=10, gamma=0.005 ...............................................
# [CV] ................... C=10, gamma=0.005, score=0.846, total=   0.3s
# [CV] C=10, gamma=0.005 ...............................................
# [CV] ................... C=10, gamma=0.005, score=0.865, total=   0.3s
# [CV] C=50, gamma=0.0001 ..............................................
# [CV] .................. C=50, gamma=0.0001, score=0.890, total=   0.4s
# [CV] C=50, gamma=0.0001 ..............................................
# [CV] .................. C=50, gamma=0.0001, score=0.886, total=   0.3s
# [CV] C=50, gamma=0.0001 ..............................................
# [CV] .................. C=50, gamma=0.0001, score=0.885, total=   0.3s
# [CV] C=50, gamma=0.0001 ..............................................
# [CV] .................. C=50, gamma=0.0001, score=0.872, total=   0.3s
# [CV] C=50, gamma=0.0001 ..............................................
# [CV] .................. C=50, gamma=0.0001, score=0.872, total=   0.3s
# [CV] C=50, gamma=0.0005 ..............................................
# [CV] .................. C=50, gamma=0.0005, score=0.890, total=   0.3s
# [CV] C=50, gamma=0.0005 ..............................................
# [CV] .................. C=50, gamma=0.0005, score=0.886, total=   0.2s
# [CV] C=50, gamma=0.0005 ..............................................
# [CV] .................. C=50, gamma=0.0005, score=0.885, total=   0.3s
# [CV] C=50, gamma=0.0005 ..............................................
# [CV] .................. C=50, gamma=0.0005, score=0.872, total=   0.3s
# [CV] C=50, gamma=0.0005 ..............................................
# [CV] .................. C=50, gamma=0.0005, score=0.872, total=   0.3s
# [CV] C=50, gamma=0.001 ...............................................
# [CV] ................... C=50, gamma=0.001, score=0.890, total=   0.3s
# [CV] C=50, gamma=0.001 ...............................................
# [CV] ................... C=50, gamma=0.001, score=0.886, total=   0.3s
# [CV] C=50, gamma=0.001 ...............................................
# [CV] ................... C=50, gamma=0.001, score=0.885, total=   0.3s
# [CV] C=50, gamma=0.001 ...............................................
# [CV] ................... C=50, gamma=0.001, score=0.872, total=   0.3s
# [CV] C=50, gamma=0.001 ...............................................
# [CV] ................... C=50, gamma=0.001, score=0.872, total=   0.3s
# [CV] C=50, gamma=0.005 ...............................................
# [CV] ................... C=50, gamma=0.005, score=0.890, total=   0.3s
# [CV] C=50, gamma=0.005 ...............................................
# [CV] ................... C=50, gamma=0.005, score=0.886, total=   0.3s
# [CV] C=50, gamma=0.005 ...............................................
# [CV] ................... C=50, gamma=0.005, score=0.885, total=   0.3s
# [CV] C=50, gamma=0.005 ...............................................
# [CV] ................... C=50, gamma=0.005, score=0.872, total=   0.3s
# [CV] C=50, gamma=0.005 ...............................................
# [CV] ................... C=50, gamma=0.005, score=0.872, total=   0.3s
# [Parallel(n_jobs=1)]: Done  80 out of  80 | elapsed:   21.0s finished
# GridSearchCV(estimator=SVC(kernel='linear'),
#              param_grid={'C': [1, 5, 10, 50],
#                          'gamma': [0.0001, 0.0005, 0.001, 0.005]},
#              verbose=3)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'C': 50, 'gamma': 0.0001}
# 0.8809807959598018

# %%
predictions = grid.predict(X_test_minmax)
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions))
# Out:
#                 precision    recall  f1-score   support
#
#      CANDIDATE       0.82      0.64      0.72       411
#      CONFIRMED       0.75      0.86      0.80       484
# FALSE POSITIVE       0.98      1.00      0.99       853
#
#       accuracy                           0.88      1748
#      macro avg       0.85      0.83      0.84      1748
#   weighted avg       0.88      0.88      0.87      1748

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'ericlee.sav'
joblib.dump(model, filename)
# Out:
# ['ericlee.sav']
